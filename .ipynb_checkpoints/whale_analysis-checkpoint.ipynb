# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
import seaborn as sns
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
whale_returns_path = Path("C:/Users/miscg/zzz/AWhaleOffthePortfolio/Resources/whale_returns.csv")

# %%
# Import the CSV of whale investor returns as Pandas DataFrames
# set the `date` as a datetime index
whale_df = pd.read_csv(whale_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
#TEMP
#return sample data
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098

# %%
# TEMP
# Use the `include` parameter set to 'all' to include all columns (and datatypes)
whale_df.describe(include='all')
# Out:
#        SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# count                1059.000000         1059.000000
# mean                    0.000179           -0.000203
# std                     0.007842            0.006977
# min                    -0.032711           -0.032099
# 25%                    -0.003594           -0.003961
# 50%                     0.000467            0.000000
# 75%                     0.004292            0.003567
# max                     0.042977            0.029338
#
#        TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# count                  1059.000000             1059.000000
# mean                     -0.000081                0.000501
# std                       0.010824                0.012831
# min                      -0.139820               -0.066505
# 25%                      -0.004746               -0.005515
# 50%                       0.000232                0.000617
# 75%                       0.005176                0.007516
# ...

# %%
# TEMP
# Use the `columns` attribute to output the column names
whale_df.columns
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC'],
#       dtype='object')

# %%
# TEMP
# Use the `dtypes` attribute to output the column names and data types
whale_df.dtypes
# Out:
# SOROS FUND MANAGEMENT LLC      float64
# PAULSON & CO.INC.              float64
# TIGER GLOBAL MANAGEMENT LLC    float64
# BERKSHIRE HATHAWAY INC         float64
# dtype: object

# %%
# TEMP
# Use the `count` function to view count of non-null values for each column
whale_df.count()
# Out:
# SOROS FUND MANAGEMENT LLC      1059
# PAULSON & CO.INC.              1059
# TIGER GLOBAL MANAGEMENT LLC    1059
# BERKSHIRE HATHAWAY INC         1059
# dtype: int64

# %%
# Checking for null
whale_df.isnull()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                       True                True
# 2015-03-03                      False               False
# 2015-03-04                      False               False
# 2015-03-05                      False               False
# 2015-03-06                      False               False
# ...                               ...                 ...
# 2019-04-25                      False               False
# 2019-04-26                      False               False
# 2019-04-29                      False               False
# 2019-04-30                      False               False
# 2019-05-01                      False               False
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                         True                    True
# 2015-03-03                        False                   False
# ...

# %%
# Count nulls
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
# Use the `dropna` function to drop whole records that have at least one null value
whale_df.dropna(inplace=True)

# %%
# TEMP
#display top 5 records again
whale_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-03                    -0.000496               -0.006569
# 2015-03-04                    -0.002534                0.004213
# 2015-03-05                     0.002355                0.006726
# 2015-03-06                    -0.008481               -0.013098
# 2015-03-09                     0.005843               -0.001652

# %%
# Check Null Counts for Each Column (Again)
# Use the `isnull` function in conjunction with the `sum` function to count the number of null values for each column
whale_df.isnull().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      0
# PAULSON & CO.INC.              0
# TIGER GLOBAL MANAGEMENT LLC    0
# BERKSHIRE HATHAWAY INC         0
# dtype: int64

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
algo_returns_path = Path("C:/Users/miscg/zzz/AWhaleOffthePortfolio/Resources/algo_returns.csv")

# %%
# Import the CSV of algo returns as Pandas DataFrames
# set the `date` as a datetime index
algo_df = pd.read_csv(algo_returns_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
algo_df.head()
# Out:
#               Algo 1  Algo 2
# Date
# 2014-05-28  0.001745     NaN
# 2014-05-29  0.003978     NaN
# 2014-05-30  0.004464     NaN
# 2014-06-02  0.005692     NaN
# 2014-06-03  0.005292     NaN

# %%
# Count nulls
algo_df.isnull().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
# Use the `dropna` function to drop whole records that have at least one null value
algo_df.dropna(inplace=True)

# %%
# TEMP
#display top 5 records again
algo_df.head()
# Out:
#               Algo 1    Algo 2
# Date
# 2014-06-05  0.004062  0.013285
# 2014-06-06  0.001857  0.008284
# 2014-06-09 -0.005012  0.005668
# 2014-06-10  0.004406 -0.000735
# 2014-06-11  0.004760 -0.003761

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
sp500_history_path = Path("C:/Users/miscg/zzz/AWhaleOffthePortfolio/Resources/sp500_history.csv")

# %%
# Import the CSV of sp500 history as Pandas DataFrames
# set the `date` as a datetime index
sp500_history_df = pd.read_csv(sp500_history_path, index_col="Date", parse_dates=True, infer_datetime_format=True)

# %%
# TEMP
#check records
sp500_history_df.head()
# Out:
#                Close
# Date
# 2019-04-23  $2933.68
# 2019-04-22  $2907.97
# 2019-04-18  $2905.03
# 2019-04-17  $2900.45
# 2019-04-16  $2907.06

# %%
# Check Data Types
# Use the `dtypes` attribute to list the column data types
sp500_history_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Remove $ sign from the Close column before converting to a float
sp500_history_df['Close'] = sp500_history_df['Close'].str.replace("$","")
# Out:
# C:\Users\miscg\Anaconda3\envs\dev\lib\site-packages\ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.

# %%
# TEMP
#check records
sp500_history_df.head()
# Out:
#               Close
# Date
# 2019-04-23  2933.68
# 2019-04-22  2907.97
# 2019-04-18  2905.03
# 2019-04-17  2900.45
# 2019-04-16  2907.06

# %%
# Fix Data Types
# Use the `as_type` function to convert `Close` from `object` to `float`
sp500_history_df['Close'] = sp500_history_df['Close'].astype(float)

# %%
# TEMP Check Data Types
# Use the `dtypes` attribute to list the column data types
sp500_history_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
# Calculate the daily return using the 'pct_change()' function
daily_returns = sp500_history_df.pct_change()

# %%
#TEMP
daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
# Use the `dropna` function to drop whole records that have at least one null value
daily_returns.dropna(inplace=True)

# %%
#TEMP
daily_returns.head()
# Out:
#                Close
# Date
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279
# 2019-04-15 -0.000509

# %%
daily_returns.columns
# Out:
# Index(['Close'], dtype='object')

# %%
# Rename `Close` Column to be specific to this portfolio.
# Set the `columns` attribute to a new list of column names
columns = ["Daily Returns"]
daily_returns.columns = columns

# %%
# TEMP
daily_returns.head()
# Out:
#             Daily Returns
# Date
# 2019-04-22      -0.008764
# 2019-04-18      -0.001011
# 2019-04-17      -0.001577
# 2019-04-16       0.002279
# 2019-04-15      -0.000509

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.

# %%
# Use the concat function to combine the DataFrames by column and perform an inner join. 
combined_df = pd.concat([whale_df, algo_df, daily_returns],axis="columns", join="inner")

# %%
# Sort datetime index in ascending order (past to present)
combined_df.sort_index(inplace=True)

# %%
# TEMP
# Display a few rows
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  Daily Returns
# Date
# 2015-03-03 -0.000949       0.004408
# 2015-03-04  0.002416      -0.001195
# 2015-03-05  0.004323       0.014378
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
# Plot daily returns of all portfolios
# Use the `plot` function to plot the daily portfolio returns
combined_df.plot(figsize=(10,5), title="Daily Returns of all portfolios")
# Out:
# <AxesSubplot:title={'center':'Daily Returns of all portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# Use the `cumprod` function to cumulatively multiply each element in the Series by it's preceding element until the end
cumulative_returns = (1 + combined_df).cumprod() - 1

# Plot cumulative returns
cumulative_returns.plot(figsize=(10,5), title="Cumulative Returns of all portfolios")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of all portfolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %%
cumulative_returns.columns
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2', 'Daily Returns'],
#       dtype='object')

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# TEST
# Box plot to visually show risk
# whale_df, algo_df, daily_returns
whale_df.plot.box()
algo_df.plot.box()
daily_returns.plot.box()
# Out:
# <AxesSubplot:>

# %%
#Boxplot to visually show risk
combined_df.boxplot(figsize=(20,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
# whale_df, algo_df, daily_returns and Cummlative_returns
# Daily Standard Deviations
daily_std_whale = whale_df.std()
daily_std_algo = algo_df.std()
daily_std_daily = daily_returns.std()

#cumulatived std
daily_std_cumulative = cumulative_returns.std()

# %%
#Daily Standard Deviations
combined_df.std()
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# Daily Returns                  0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
daily_std_daily = daily_returns.std()
daily_std_daily.head()
# Out:
# Daily Returns    0.008135
# dtype: float64

# %%
# Determine which portfolios are riskier than the S&P 500
# Identify the stock with the most risk
daily_std_cumulative = daily_std_cumulative.sort_values(ascending=False)
daily_std_cumulative.head()
# Out:
# BERKSHIRE HATHAWAY INC         0.241382
# Algo 1                         0.231772
# TIGER GLOBAL MANAGEMENT LLC    0.149652
# Algo 2                         0.131642
# Daily Returns                  0.114846
# dtype: float64

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std_cumulative * np.sqrt(252)
annualized_std.head()
# Out:
# BERKSHIRE HATHAWAY INC         3.831820
# Algo 1                         3.679263
# TIGER GLOBAL MANAGEMENT LLC    2.375658
# Algo 2                         2.089756
# Daily Returns                  1.823124
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
#TEST
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# 2015-03-05                     0.002355                0.006726 -0.000955
# 2015-03-06                    -0.008481               -0.013098 -0.004957
# 2015-03-09                     0.005843               -0.001652 -0.005447
#
#               Algo 2  Daily Returns
# Date
# 2015-03-03 -0.000949       0.004408
# 2015-03-04  0.002416      -0.001195
# 2015-03-05  0.004323       0.014378
# ...

# %%
#TEST
combined_df.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# 21day_std_all = combined_df.rolling(window=21).std()

# Plot the rolling standard deviation
combined_df.rolling(window=21).std().plot(figsize=(15,8))
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation = combined_df.corr()

# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# Daily Returns                                 0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
# SOROS FUNG MANAGEMENT LLC
covariance_soros = combined_df['SOROS FUND MANAGEMENT LLC'].cov(combined_df['Daily Returns'])
covariance_soros
# Out:
# 3.8897269830622025e-08

# %%
# Calculate variance of S&P 500
variance_sp500 = combined_df['Daily Returns'].var()
variance_sp500
# Out:
# 7.373467552840441e-05

# %%
# Computing beta  
# beta = covariance /variance
beta_soros = covariance_soros /  variance_sp500
beta_soros
# Out:
# 0.0005275302230853086

# %%
rolling_covariance = combined_df['SOROS FUND MANAGEMENT LLC'].rolling(window=60).cov(combined_df['Daily Returns'])
rolling_variance = combined_df['Daily Returns'].rolling(window=60).var()

# %%
# Plot beta trend
rolling_beta_soros = rolling_covariance / rolling_variance
rolling_beta_soros.plot(figsize=(20, 10), title='Rolling 30-Day Beta of SOROS FUND MANAGEMENT LLC')
# Out:
# <AxesSubplot:title={'center':'Rolling 30-Day Beta of SOROS FUND MANAGEMENT LLC'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_df.ewm(halflife=21).std().plot(figsize=(10,10))
#cumulative_returns = (1 + combined_df).cumprod() - 1
#cumulative_returns.plot()
# Out:
# <AxesSubplot:xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
combined_df.columns
# Out:
# Index(['SOROS FUND MANAGEMENT LLC', 'PAULSON & CO.INC. ',
#        'TIGER GLOBAL MANAGEMENT LLC', 'BERKSHIRE HATHAWAY INC', 'Algo 1',
#        'Algo 2', 'Daily Returns'],
#       dtype='object')

# %%
# Annualized Sharpe Ratios
# Calculate Sharpe Ratio
sharpe_ratios = (combined_df.mean() * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# Daily Returns                 -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
# Plot sharpe ratios
sharpe_ratios.plot(kind="bar", title="Sharpe Ratios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Write your answer here!

# %%
# Calculate Sharpe Ratio against daily returns
sharpe_ratios = ((combined_df.mean()-combined_df['Daily Returns'].mean()) * 252) / (combined_df.std() * np.sqrt(252))
sharpe_ratios
# Out:
# SOROS FUND MANAGEMENT LLC      0.906838
# PAULSON & CO.INC.              0.142411
# TIGER GLOBAL MANAGEMENT LLC    0.278448
# BERKSHIRE HATHAWAY INC         0.951436
# Algo 1                         1.953767
# Algo 2                         1.018189
# Daily Returns                  0.000000
# dtype: float64

# %% [markdown]
# ---

# %%
# Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios
print("The algorithmic strategies did outpurform the market(S&P 500) and the whales portfolios!")
# Out:
# The algorithmic strategies did outpurform the market(S&P 500) and the whales portfolios!

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
#AAPL
aapl_path = Path("C:/Users/miscg/zzz/AWhaleOffthePortfolio/Resources/aapl_historical.csv")

# %%
# Reading data from 2nd stock
#COST
cost_path = Path("C:/Users/miscg/zzz/AWhaleOffthePortfolio/Resources/cost_historical.csv")

# %%
# Reading data from 3rd stock
# GOOG
goog_path = Path("C:/Users/miscg/zzz/AWhaleOffthePortfolio/Resources/goog_historical.csv")

# %%
# create dataframes

aapl_df = pd.read_csv(aapl_path, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
cost_df = pd.read_csv(cost_path, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)
goog_df = pd.read_csv(goog_path, index_col="Trade DATE", parse_dates=True, infer_datetime_format=True)

# %%
#Rename NOCP column to be Stock symble for when combining dataframes
aapl_df.rename( columns={"NOCP":"AAPL"},inplace = True )
cost_df.rename( columns={"NOCP":"COST"},inplace = True )
goog_df.rename( columns={"NOCP":"GOOG"},inplace = True )

# %%
# Combine all stocks in a single DataFrame
# Use the concat function to combine the DataFrames by column and perform an inner join. 
combined_custom_df = pd.concat([aapl_df, cost_df, goog_df],axis="columns", join="inner")

# %%
combined_custom_df.head()
# Out:
#            Symbol    AAPL Symbol    COST Symbol     GOOG
# Trade DATE
# 2019-05-09   AAPL  200.72   COST  243.47   GOOG  1162.38
# 2019-05-08   AAPL  202.90   COST  241.34   GOOG  1166.27
# 2019-05-07   AAPL  202.86   COST  240.18   GOOG  1174.10
# 2019-05-06   AAPL  208.48   COST  244.23   GOOG  1189.39
# 2019-05-03   AAPL  211.75   COST  244.62   GOOG  1185.40

# %%
# Reset Date index
# Sort datetime index in ascending order (past to present)
combined_custom_df.sort_index(inplace=True)

# %%
#TEMP show sample
combined_custom_df.head()
# Out:
#            Symbol    AAPL Symbol    COST Symbol     GOOG
# Trade DATE
# 2018-05-11   AAPL  188.59   COST  195.76   GOOG  1098.26
# 2018-05-14   AAPL  188.15   COST  195.88   GOOG  1100.20
# 2018-05-15   AAPL  186.44   COST  195.48   GOOG  1079.23
# 2018-05-16   AAPL  188.18   COST  198.71   GOOG  1081.77
# 2018-05-17   AAPL  186.99   COST  199.60   GOOG  1078.59

# %%
# Reorganize portfolio data by having a column per symbol
#remove extra columns with drop command
combined_custom_df.drop(columns=['Symbol'], axis=1,inplace = True)

# %%
#TEMP show sample
combined_custom_df.head()
# Out:
#               AAPL    COST     GOOG
# Trade DATE
# 2018-05-11  188.59  195.76  1098.26
# 2018-05-14  188.15  195.88  1100.20
# 2018-05-15  186.44  195.48  1079.23
# 2018-05-16  188.18  198.71  1081.77
# 2018-05-17  186.99  199.60  1078.59

# %%
# Calculate daily returns
daily_returns_custom = combined_custom_df.pct_change()
daily_returns_custom.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-11       NaN       NaN       NaN
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940

# %%
# Drop NAs
# Use the `dropna` function to drop whole records that have at least one null value
daily_returns_custom.dropna(inplace=True)

# %%
# Display sample data
daily_returns_custom.head()
# Out:
#                 AAPL      COST      GOOG
# Trade DATE
# 2018-05-14 -0.002333  0.000613  0.001766
# 2018-05-15 -0.009088 -0.002042 -0.019060
# 2018-05-16  0.009333  0.016523  0.002354
# 2018-05-17 -0.006324  0.004479 -0.002940
# 2018-05-18 -0.003637 -0.003206 -0.011339

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
portfolio_return = daily_returns_custom.dot(weights)

# %%
# Display sample data
portfolio_return.head()
# Out:
# Trade DATE
# 2018-05-14    0.000015
# 2018-05-15   -0.010064
# 2018-05-16    0.009403
# 2018-05-17   -0.001595
# 2018-05-18   -0.006061
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
combined_custom = pd.concat([portfolio_return, combined_df], axis='columns', join='inner')

# %%
#rename custom column
combined_custom.rename(columns= {0: "Custom"},inplace = True )

# %%
# Only compare dates where return data exists for all the stocks (drop NaNs)
# Use the `dropna` function to drop whole records that have at least one null value
combined_custom.dropna(inplace=True)

# %%
# Sort datetime index in ascending order (past to present)
combined_custom.sort_index(inplace=True)

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized `std`
combined_custom.std()
annualized_variance_custom = (combined_custom.var()*252)
annualized_std_custom = np.sqrt(annualized_variance_custom)
annualized_std_custom
# Out:
# Custom                         0.211627
# SOROS FUND MANAGEMENT LLC      0.146812
# PAULSON & CO.INC.              0.116928
# TIGER GLOBAL MANAGEMENT LLC    0.232898
# BERKSHIRE HATHAWAY INC         0.247305
# Algo 1                         0.133927
# Algo 2                         0.139499
# Daily Returns                  0.152469
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
# Plot rolling standard deviation
combined_custom.rolling(window=21).std().plot(figsize=(15,8))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_custom = combined_custom.corr()
correlation_custom
# Out:
#                                Custom  SOROS FUND MANAGEMENT LLC  \
# Custom                       1.000000                   0.732548
# SOROS FUND MANAGEMENT LLC    0.732548                   1.000000
# PAULSON & CO.INC.            0.643828                   0.791802
# TIGER GLOBAL MANAGEMENT LLC  0.390961                   0.477844
# BERKSHIRE HATHAWAY INC       0.800558                   0.816197
# Algo 1                       0.260331                   0.336909
# Algo 2                       0.739020                   0.862583
# Daily Returns                0.005603                  -0.028256
#
#                              PAULSON & CO.INC.   TIGER GLOBAL MANAGEMENT LLC  \
# Custom                                 0.643828                     0.390961
# SOROS FUND MANAGEMENT LLC              0.791802                     0.477844
# PAULSON & CO.INC.                      1.000000                     0.484869
# ...

# %%
sns.heatmap(correlation_custom, vmin=-1, vmax=1,)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta
# split up calculations below
# beta = covariance /variance

# %%
#covariance
covariance_custom = combined_custom['Custom'].cov(combined_df['Daily Returns'])
covariance_custom
# Out:
# 7.174773010758039e-07

# %%
# Calculate variance of S&P 500
variance_sp500 = combined_df['Daily Returns'].var()
variance_sp500
# Out:
# 7.373467552840441e-05

# %%
# Computing beta  
# beta = covariance /variance
beta_custom = covariance_custom /  variance_sp500
beta_custom
# Out:
# 0.009730527678248398

# %%
#rolling
rolling_covariance_custom = combined_custom['Custom'].rolling(window=60).cov(combined_df['Daily Returns'])
rolling_variance = combined_df['Daily Returns'].rolling(window=60).var()

# %%
# Plot beta trend
rolling_beta_custom = rolling_covariance_custom / rolling_variance
rolling_beta_custom.plot(figsize=(20, 10), title='Rolling 60-Day Beta of Custom Portfolio vs S&P500')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta of Custom Portfolio vs S&P500'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios
sharpe_ratios_final = (combined_custom.mean() * 252) / ((combined_custom).std() * np.sqrt(252))
sharpe_ratios_final
# Out:
# Custom                         0.876152
# SOROS FUND MANAGEMENT LLC      0.380007
# PAULSON & CO.INC.              0.227577
# TIGER GLOBAL MANAGEMENT LLC   -1.066635
# BERKSHIRE HATHAWAY INC         0.103006
# Algo 1                         2.001260
# Algo 2                         0.007334
# Daily Returns                 -0.427676
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
sharpe_ratios_final.plot(kind="bar", title="Sharpe Ratios Final")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios Final'}>

# %% [markdown]
# ### How does your portfolio do?
#
# Write your answer here!

# %%
#answer on portfolio success
print("Custom portfolio was very successful over time fram and beat every return except for Algorithm 1,  This was primarily due to the blue chip tech stocks in portfolio.")
# Out:
# Custom portfolio was very successful over time fram and beat every return except for Algorithm 1,  This was primarily due to the blue chip tech stocks in portfolio.
